# %% [markdown]
# <a href="https://colab.research.google.com/github/KangMonkey/python_assignments/blob/main/Assignment_1_CV_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy import array
vec=np.array([1,2,3,4,5])
print(vec)
# Out:
# [1 2 3 4 5]

# %%
from numpy import array
x=array([1,2,3,4,5])
print(x)
y=array([2,3,6,7,8])
print(y)
z=x+y
print(z)
# Out:
# [1 2 3 4 5]
# [2 3 6 7 8]
# [ 3  5  9 11 13]

# %%
from numpy import array
x=array([1,2,3,4,5])
print(x)
s=5
print(s)
z=s*x
print(z)
# Out:
# [1 2 3 4 5]
# 5
# [ 5 10 15 20 25]

# %%
from numpy import array
x=array([1,2,3,4,5])
print(x)
y=array([2,3,6,7,8])
print(y)
z=x.dot(y)
print(z)
# Out:
# [1 2 3 4 5]
# [2 3 6 7 8]
# 94

# %%
from numpy import array
vec=array([1,2,3,4,5])
print(vec)
# Out:
# [1 2 3 4 5]

# %%
import matplotlib.pyplot as plt
import matplotlib.image as np
img=np.imread("Pythonp.jpg")
plt.axis("off")
img_plot=plt.imshow(img)
plt.show()
